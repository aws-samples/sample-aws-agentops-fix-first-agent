# %% [markdown]
# # A/B Testing with Amazon Bedrock AgentCore (Windows)
#
# This notebook demonstrates **target-based A/B testing** using Amazon Bedrock AgentCore.
#
# All cells use `%%cmd`. No Python or bash required.
#
# **Prerequisites:** Python 3.12+, `uv`, Node.js, AWS CLI >= 2.34, CDK bootstrapped, Bedrock model access.
#
# **Run this notebook from the `ab_testing/` directory.**

# %% [markdown]
# ## 1. Check Prerequisites

# %%
# %%cmd
# .\check_prerequisites.bat

# %% [markdown]
# ## 2. Package Agents

# %%
# %%cmd
# .\package_agents.bat ..\target_based_variants\agents

# %% [markdown]
# ## 3. Deploy Runtimes + Evaluation Configs

# %%
# %%cmd
# .\deploy_agents.bat ..\target_based_variants\cdk_ab_testing

# %% [markdown]
# ## 4. Wait for Runtimes to Become READY

# %%
# %%cmd
# .\wait_for_runtimes.bat

# %% [markdown]
# ## 5. Deploy Gateway + Targets + A/B Test

# %%
# %%cmd
# .\deploy_testing_infra.bat ..\target_based_variants\cdk_ab_gateway

# %% [markdown]
# ## 6. Send Traffic Through Gateway

# %%
# %%cmd
# .\send_traffic.bat

# %% [markdown]
# ## 7. Check A/B Test Results
#
# Re-run this cell after ~15 minutes to see statistical results.

# %%
# %%cmd
# .\check_ab_results.bat

# %% [markdown]
# ## 8. Stop the A/B Test

# %%
# %%cmd
# .\stop_ab_test.bat

# %% [markdown]
# ## 9. Cleanup

# %%
# %%cmd
# .\cleanup_all.bat
